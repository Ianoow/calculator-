# %% [markdown]
# <a href="https://colab.research.google.com/github/Ianoow/calculator-/blob/main/accidents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('accidents.xlsx')
df
# Out:
#     TIME 24 HOURS  BASE/SUB BASE        COUNTY                ROAD  \
# 0             630          KITUI       MAKUENI       KITUI-ITHOKWE
# 1             830            VOI  TAITA TAVETA     MOMBASA-NAIROBI
# 2            1330      MARIAKANI        KILIFI     MOMBASA-NAIROBI
# 3            2100  ONGATA RONGAI        NAKURU      NAKURU-NAIROBI
# 4            1900          MATUU      MACHAKOS        MATUU-MWINGI
# ..            ...            ...           ...                 ...
# 373          2110           JUJA        KIAMBU  THIKA SUPERHIGHWAY
# 374          2040        KAJIADO       KAJIADO     KAJIADO NAMANGA
# 375          2040        KAJIADO       KAJIADO     KAJIADO NAMANGA
# 376          1830         KAYOLE       NAIROBI          SPINE ROAD
# 377          2230      MAKONGENI       NAIROBI          JOGOO ROAD
#
#                            PLACE  \
# 0                   KITUI SCHOOL
# 1                         IKANGA
# 2                       KATOLANI
# ...

# %%
df.describe()
# Out:
#        CAUSE CODE         NO.                Date DD/MM/YYYY
# count  372.000000  378.000000                            378
# mean    47.430108    1.145503  2016-05-10 11:10:28.571428608
# min      1.000000    1.000000            2016-04-01 00:00:00
# 25%     17.000000    1.000000            2016-04-13 00:00:00
# 50%     29.000000    1.000000            2016-04-26 00:00:00
# 75%     79.000000    1.000000            2016-06-11 00:00:00
# max     98.000000    8.000000            2016-06-25 00:00:00
# std     33.860232    0.696709                            NaN
